# %% [markdown]
# # 001 — Project Scope and Modeling Conventions
#
# ## Purpose
# Define the digital twin, its boundaries, coordinate conventions, state variables, assumptions, validation philosophy, and research questions before building coupled GNC models.
#
# ## Questions
# 1. What physical system is represented?
# 2. Which states constitute simulation truth?
# 3. Which quantities are measured rather than known?
# 4. Which reference frames and quaternion conventions are used?
# 5. How will each subsystem be independently validated?
# 6. Which final experiment can support a publication-quality technical claim?

# %% [markdown]
# ## Initial system decomposition
# - Environment / orbit
# - Rigid-body spacecraft dynamics
# - Sensors
# - State estimator
# - Guidance / reference generation
# - Controller
# - Actuators
# - Telemetry / metrics / visualization

# %%
import numpy as np

np.set_printoptions(precision=6, suppress=True)
print('Spacecraft Dynamics project initialized.')

# %% [markdown]
# ## Definition of done for Investigation 001
# - [ ] Freeze units and frame conventions
# - [ ] Define truth state vector
# - [ ] Define initial baseline spacecraft
# - [ ] Define first validation cases
# - [ ] Write one-paragraph publication hypothesis candidate
